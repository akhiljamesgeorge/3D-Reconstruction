# %%
"""
Created on Sat Apr 11 15:04:23 2020
@author: jamesa
"""

import pathlib  #to check the path and verify if the required SW is allready installed
from google.colab import drive   # Mount Google Drive
drive.mount('/content/drive')

print("\nLaunching 3D-Reconstruction application on Google colab\n")

# Folder paths
currentDir = "/content/Project-3D" #work directory
print("Locating input images in google drive...\n")
inputFolder = "/content/drive/My\ Drive/Colab\ Notebooks/3D-Reconstruction/Input" # Folder in Google drive with input images
outputFolder = "/content/drive/My\ Drive/Colab\ Notebooks/3D-Reconstruction/Output" # Folder in Google drive where output will be finally store/moved
inputFiles = currentDir + "/input" # folder in work directory with the input images
outputFiles = currentDir + "/output" # folder in work directory with output files
meshroomFolder = currentDir + "/meshroom" # folder in work directory with all meshroom files

# Creating all directories
# !mkdir -v $currentDir # will be skipped if allready existing
#inputFolder should allready be created in google drive and should contain images used for 3D reconstruction
# !mkdir -v $outputFolder  # will be skipped if allready existing
# !mkdir -v $inputFiles #temporary folder in work directory to store input images. Should be deleted once 3D is made.
# !mkdir -v $outputFiles #temporary folder in work directory to store 3D output files. Should be deleted once 3D output is moved to google drive folder.
# !mkdir -v $meshroomFolder # will be skipped if allready existing

# Go to work directory
# %cd $currentDir

# Make copy of input image files from the google drive folder to the input folder of work directory
print("\nCopying input images from google drive to work directory...\n")
# %cp -arv $inputFolder/* $inputFiles

# Check if meshroom is allready installed. If not, download and install meshroom
meshroom_files = pathlib.Path("/content/Project-3D/meshroom/Meshroom-2019.2.0")

if not meshroom_files.exists ():
  print("\nMeshroom not found.\nInstalling Meshroom...")
  # !wget -N https://github.com/alicevision/meshroom/releases/download/v2019.2.0/Meshroom-2019.2.0-linux.tar.gz
  # !tar xzf Meshroom-2019.2.0-linux.tar.gz -C $meshroomFolder
  # %mv -v /content/Project-3D/meshroom/Meshroom-2019.2.0/* $meshroomFolder
else :
   print ("\nMeshroom is allredy installed. Skipping a new installation...")

# Execute Meshroom
startMeshroom = meshroomFolder+"/meshroom_photogrammetry"
# !$startMeshroom --input $inputFiles --output $outputFiles

# Copy Output from work directory to the output folder in google drive
print("\nMoving output files to google drive...\n")
# %cp -arv $outputFiles/* $outputFolder

# Remove the input and output folder in work directory
print("\nRemoving all temporary files...\n")
# %rm -Rv $inputFiles
# %rm -Rv $outputFiles

print('#########################################################################################################################################################################################################')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Launching 3D-Reconstruction application on Google colab
#
# Locating input images in google drive...
#
# mkdir: cannot create directory ‘/content/Project-3D’: File exists
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Output’: File exists
# mkdir: created directory '/content/Project-3D/input'
# mkdir: created directory '/content/Project-3D/output'
# mkdir: cannot create directory ‘/content/Project-3D/meshroom’: File exists
# /content/Project-3D
#
# Copying input images from google drive to work directory...
#
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172509.jpg' -> '/content/Project-3D/input/20200411_172509.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172527.jpg' -> '/content/Project-3D/input/20200411_172527.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172533.jpg' -> '/content/Project-3D/input/20200411_172533.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172542.jpg' -> '/content/Project-3D/input/20200411_172542.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172547.jpg' -> '/content/Project-3D/input/20200411_172547.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172552.jpg' -> '/content/Project-3D/input/20200411_172552.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172558.jpg' -> '/content/Project-3D/input/20200411_172558.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172625.jpg' -> '/content/Project-3D/input/20200411_172625.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172643.jpg' -> '/content/Project-3D/input/20200411_172643.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172651.jpg' -> '/content/Project-3D/input/20200411_172651.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172655.jpg' -> '/content/Project-3D/input/20200411_172655.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172659.jpg' -> '/content/Project-3D/input/20200411_172659.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172713.jpg' -> '/content/Project-3D/input/20200411_172713.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172718.jpg' -> '/content/Project-3D/input/20200411_172718.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172725.jpg' -> '/content/Project-3D/input/20200411_172725.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172734.jpg' -> '/content/Project-3D/input/20200411_172734.jpg'
# '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Input/20200411_172835.jpg' -> '/content/Project-3D/input/20200411_172835.jpg'
#
# Meshroom is allredy installed. Skipping a new installation...
# Plugins loaded:  CameraCalibration, CameraInit, CameraLocalization, CameraRigCalibration, CameraRigLocalization, ConvertSfMFormat, DepthMap, DepthMapFilter, ExportAnimatedCamera, ExportColoredPointCloud, ExportMaya, FeatureExtraction, FeatureMatching, ImageMatching, ImageMatchingMultiSfM, KeyframeSelection, LDRToHDR, MeshDecimate, MeshDenoising, MeshFiltering, MeshResampling, Meshing, PrepareDenseScene, Publish, SfMAlignment, SfMTransform, StructureFromMotion, Texturing
# Program called with the following parameters:
#  * allowSingleView = 1
#  * defaultCameraModel = "" (default)
#  * defaultFieldOfView = 45
#  * defaultFocalLengthPix = -1 (default)
#  * defaultIntrinsic = "" (default)
#  * groupCameraFallback =  Unknown Type "20EGroupCameraFallback"
#  * imageFolder = "" (default)
#  * input = "/tmp/tmp90bv5zqe/CameraInit/c448939571d5c70b05c9ae4ad416ada37d6273ca//viewpoints.sfm"
#  * output = "/tmp/tmp90bv5zqe/CameraInit/c448939571d5c70b05c9ae4ad416ada37d6273ca/cameraInit.sfm"
#  * sensorDatabase = "/content/Project-3D/meshroom/aliceVision/share/aliceVision/cameraSensors.db"
#  * verboseLevel = "info"
#
# [15:31:26.473573][warning] Some image(s) have no serial number to identify the camera/lens device.
# This makes it impossible to correctly group the images by device if you have used multiple identical (same model) camera devices.
# The reconstruction will assume that only one device has been used, so if 2 images share the same focal length approximation they will share the same internal camera parameters.
# 17 image(s) are concerned.
# [15:31:26.478602][info] CameraInit report:
# 	- # views listed: 17
# 	   - # views with an initialized intrinsic listed: 17
# 	   - # views without metadata (with a default intrinsic): 0
# 	- # intrinsics listed: 1
# Nodes to execute:  ['CameraInit_1', 'FeatureExtraction_1', 'ImageMatching_1', 'FeatureMatching_1', 'StructureFromMotion_1', 'PrepareDenseScene_1', 'DepthMap_1', 'DepthMapFilter_1', 'Meshing_1', 'MeshFiltering_1', 'Texturing_1', 'Publish_1']
#
# [1/12] CameraInit
#  - commandLine: aliceVision_cameraInit  --sensorDatabase "/content/Project-3D/meshroom/aliceVision/share/aliceVision/cameraSensors.db" --defaultFieldOfView 45.0 --groupCameraFallback folder --verboseLevel info --output "/tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5/cameraInit.sfm" --allowSingleView 1  --input "/tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5//viewpoints.sfm"
#  - logFile: /tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5/log
#  - elapsed time: 0:00:00.059979
#
# [2/12] FeatureExtraction
#  - commandLine: aliceVision_featureExtraction  --input "/tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5/cameraInit.sfm" --describerTypes sift --describerPreset normal --forceCpuExtraction True --verboseLevel info --output "/tmp/MeshroomCache/FeatureExtraction/ac4dac3c6f7afb29047d59ad59d66dc7ed0fc082" --rangeStart 0 --rangeSize 40
#  - logFile: /tmp/MeshroomCache/FeatureExtraction/ac4dac3c6f7afb29047d59ad59d66dc7ed0fc082/0.log
#  - elapsed time: 0:00:59.183614
#
# [3/12] ImageMatching
#  - commandLine: aliceVision_imageMatching  --input "/tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5/cameraInit.sfm" --featuresFolders "/tmp/MeshroomCache/FeatureExtraction/ac4dac3c6f7afb29047d59ad59d66dc7ed0fc082" --tree "/content/Project-3D/meshroom/aliceVision/share/aliceVision/vlfeat_K80L3.SIFT.tree" --weights "" --minNbImages 200 --maxDescriptors 500 --nbMatches 50 --verboseLevel info --output "/tmp/MeshroomCache/ImageMatching/e0038d812b4276422fb9ceda1ec62bf61e4aef18/imageMatches.txt"
#  - logFile: /tmp/MeshroomCache/ImageMatching/e0038d812b4276422fb9ceda1ec62bf61e4aef18/log
#  - elapsed time: 0:00:00.043617
#
# [4/12] FeatureMatching
#  - commandLine: aliceVision_featureMatching  --input "/tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5/cameraInit.sfm" --featuresFolders "/tmp/MeshroomCache/FeatureExtraction/ac4dac3c6f7afb29047d59ad59d66dc7ed0fc082" --imagePairsList "/tmp/MeshroomCache/ImageMatching/e0038d812b4276422fb9ceda1ec62bf61e4aef18/imageMatches.txt" --describerTypes sift --photometricMatchingMethod ANN_L2 --geometricEstimator acransac --geometricFilterType fundamental_matrix --distanceRatio 0.8 --maxIteration 2048 --geometricError 0.0 --maxMatches 0 --savePutativeMatches False --guidedMatching False --exportDebugFiles False --verboseLevel info --output "/tmp/MeshroomCache/FeatureMatching/710f9dbd764fdc44a3868204aedecde9ad5149d9" --rangeStart 0 --rangeSize 20
#  - logFile: /tmp/MeshroomCache/FeatureMatching/710f9dbd764fdc44a3868204aedecde9ad5149d9/0.log
#  - elapsed time: 0:00:54.730872
#
# [5/12] StructureFromMotion
#  - commandLine: aliceVision_incrementalSfM  --input "/tmp/MeshroomCache/CameraInit/5d964dc3bada430b09a9e1de345da74188cd3cd5/cameraInit.sfm" --featuresFolders "/tmp/MeshroomCache/FeatureExtraction/ac4dac3c6f7afb29047d59ad59d66dc7ed0fc082" --matchesFolders "/tmp/MeshroomCache/FeatureMatching/710f9dbd764fdc44a3868204aedecde9ad5149d9" --describerTypes sift --localizerEstimator acransac --localizerEstimatorMaxIterations 4096 --localizerEstimatorError 0.0 --lockScenePreviouslyReconstructed False --useLocalBA True --localBAGraphDistance 1 --maxNumberOfMatches 0 --minInputTrackLength 2 --minNumberOfObservationsForTriangulation 2 --minAngleForTriangulation 3.0 --minAngleForLandmark 2.0 --maxReprojectionError 4.0 --minAngleInitialPair 5.0 --maxAngleInitialPair 40.0 --useOnlyMatchesFromInputFolder False --useRigConstraint True --lockAllIntrinsics False --initialPairA "" --initialPairB "" --interFileExtension .abc --verboseLevel info --output "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --outputViewsAndPoses "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/cameras.sfm" --extraInfoFolder "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7"
#  - logFile: /tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/log
#  - elapsed time: 0:00:15.563429
#
# [6/12] PrepareDenseScene
#  - commandLine: aliceVision_prepareDenseScene  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --outputFileType exr --saveMetadata True --saveMatricesTxtFiles False --evCorrection False --verboseLevel info --output "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --rangeStart 0 --rangeSize 40
#  - logFile: /tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39/0.log
#  - elapsed time: 0:00:17.995666
#
# [7/12](1/6) DepthMap
#  - commandLine: aliceVision_depthMapEstimation  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --downscale 2 --minViewAngle 2.0 --maxViewAngle 70.0 --sgmMaxTCams 10 --sgmWSH 4 --sgmGammaC 5.5 --sgmGammaP 8.0 --refineMaxTCams 6 --refineNSamplesHalf 150 --refineNDepthsToRefine 31 --refineNiters 100 --refineWSH 3 --refineSigma 15 --refineGammaC 15.5 --refineGammaP 8.0 --refineUseTcOrRcPixSize False --exportIntermediateResults False --nbGPUs 0 --verboseLevel info --output "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --rangeStart 0 --rangeSize 3
#  - logFile: /tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26/0.log
#  - elapsed time: 0:00:47.339255
#
# [7/12](2/6) DepthMap
#  - commandLine: aliceVision_depthMapEstimation  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --downscale 2 --minViewAngle 2.0 --maxViewAngle 70.0 --sgmMaxTCams 10 --sgmWSH 4 --sgmGammaC 5.5 --sgmGammaP 8.0 --refineMaxTCams 6 --refineNSamplesHalf 150 --refineNDepthsToRefine 31 --refineNiters 100 --refineWSH 3 --refineSigma 15 --refineGammaC 15.5 --refineGammaP 8.0 --refineUseTcOrRcPixSize False --exportIntermediateResults False --nbGPUs 0 --verboseLevel info --output "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --rangeStart 3 --rangeSize 3
#  - logFile: /tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26/1.log
#  - elapsed time: 0:00:50.107009
#
# [7/12](3/6) DepthMap
#  - commandLine: aliceVision_depthMapEstimation  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --downscale 2 --minViewAngle 2.0 --maxViewAngle 70.0 --sgmMaxTCams 10 --sgmWSH 4 --sgmGammaC 5.5 --sgmGammaP 8.0 --refineMaxTCams 6 --refineNSamplesHalf 150 --refineNDepthsToRefine 31 --refineNiters 100 --refineWSH 3 --refineSigma 15 --refineGammaC 15.5 --refineGammaP 8.0 --refineUseTcOrRcPixSize False --exportIntermediateResults False --nbGPUs 0 --verboseLevel info --output "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --rangeStart 6 --rangeSize 3
#  - logFile: /tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26/2.log
#  - elapsed time: 0:00:48.762262
#
# [7/12](4/6) DepthMap
#  - commandLine: aliceVision_depthMapEstimation  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --downscale 2 --minViewAngle 2.0 --maxViewAngle 70.0 --sgmMaxTCams 10 --sgmWSH 4 --sgmGammaC 5.5 --sgmGammaP 8.0 --refineMaxTCams 6 --refineNSamplesHalf 150 --refineNDepthsToRefine 31 --refineNiters 100 --refineWSH 3 --refineSigma 15 --refineGammaC 15.5 --refineGammaP 8.0 --refineUseTcOrRcPixSize False --exportIntermediateResults False --nbGPUs 0 --verboseLevel info --output "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --rangeStart 9 --rangeSize 3
#  - logFile: /tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26/3.log
#  - elapsed time: 0:00:44.405404
#
# [7/12](5/6) DepthMap
#  - commandLine: aliceVision_depthMapEstimation  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --downscale 2 --minViewAngle 2.0 --maxViewAngle 70.0 --sgmMaxTCams 10 --sgmWSH 4 --sgmGammaC 5.5 --sgmGammaP 8.0 --refineMaxTCams 6 --refineNSamplesHalf 150 --refineNDepthsToRefine 31 --refineNiters 100 --refineWSH 3 --refineSigma 15 --refineGammaC 15.5 --refineGammaP 8.0 --refineUseTcOrRcPixSize False --exportIntermediateResults False --nbGPUs 0 --verboseLevel info --output "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --rangeStart 12 --rangeSize 3
#  - logFile: /tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26/4.log
#  - elapsed time: 0:00:46.114999
#
# [7/12](6/6) DepthMap
#  - commandLine: aliceVision_depthMapEstimation  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --downscale 2 --minViewAngle 2.0 --maxViewAngle 70.0 --sgmMaxTCams 10 --sgmWSH 4 --sgmGammaC 5.5 --sgmGammaP 8.0 --refineMaxTCams 6 --refineNSamplesHalf 150 --refineNDepthsToRefine 31 --refineNiters 100 --refineWSH 3 --refineSigma 15 --refineGammaC 15.5 --refineGammaP 8.0 --refineUseTcOrRcPixSize False --exportIntermediateResults False --nbGPUs 0 --verboseLevel info --output "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --rangeStart 15 --rangeSize 3
#  - logFile: /tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26/5.log
#  - elapsed time: 0:00:30.883194
#
# [8/12](1/2) DepthMapFilter
#  - commandLine: aliceVision_depthMapFiltering  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --depthMapsFolder "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --minViewAngle 2.0 --maxViewAngle 70.0 --nNearestCams 10 --minNumOfConsistentCams 3 --minNumOfConsistentCamsWithLowSimilarity 4 --pixSizeBall 0 --pixSizeBallWithLowSimilarity 0 --computeNormalMaps False --verboseLevel info --output "/tmp/MeshroomCache/DepthMapFilter/9dc7a53fa9218b29f1787c1effa3a49093f65fee" --rangeStart 0 --rangeSize 10
#  - logFile: /tmp/MeshroomCache/DepthMapFilter/9dc7a53fa9218b29f1787c1effa3a49093f65fee/0.log
#  - elapsed time: 0:01:05.673625
#
# [8/12](2/2) DepthMapFilter
#  - commandLine: aliceVision_depthMapFiltering  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --depthMapsFolder "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --minViewAngle 2.0 --maxViewAngle 70.0 --nNearestCams 10 --minNumOfConsistentCams 3 --minNumOfConsistentCamsWithLowSimilarity 4 --pixSizeBall 0 --pixSizeBallWithLowSimilarity 0 --computeNormalMaps False --verboseLevel info --output "/tmp/MeshroomCache/DepthMapFilter/9dc7a53fa9218b29f1787c1effa3a49093f65fee" --rangeStart 10 --rangeSize 10
#  - logFile: /tmp/MeshroomCache/DepthMapFilter/9dc7a53fa9218b29f1787c1effa3a49093f65fee/1.log
#  - elapsed time: 0:00:48.721235
#
# [9/12] Meshing
#  - commandLine: aliceVision_meshing  --input "/tmp/MeshroomCache/StructureFromMotion/4591b6836886bdc22d20f815145c11d12e63ffe7/sfm.abc" --depthMapsFolder "/tmp/MeshroomCache/DepthMap/774f54a1f52041832928a362717d25270eb83d26" --depthMapsFilterFolder "/tmp/MeshroomCache/DepthMapFilter/9dc7a53fa9218b29f1787c1effa3a49093f65fee" --estimateSpaceFromSfM True --estimateSpaceMinObservations 3 --estimateSpaceMinObservationAngle 10 --maxInputPoints 50000000 --maxPoints 5000000 --maxPointsPerVoxel 1000000 --minStep 2 --partitioning singleBlock --repartition multiResolution --angleFactor 15.0 --simFactor 15.0 --pixSizeMarginInitCoef 2.0 --pixSizeMarginFinalCoef 4.0 --voteMarginFactor 4.0 --contributeMarginFactor 2.0 --simGaussianSizeInit 10.0 --simGaussianSize 10.0 --minAngleThreshold 1.0 --refineFuse True --addLandmarksToTheDensePointCloud False --colorizeOutput False --saveRawDensePointCloud False --verboseLevel info --outputMesh "/tmp/MeshroomCache/Meshing/0606d27149a3b432615e25b93c360c9e38acf92e/mesh.obj" --output "/tmp/MeshroomCache/Meshing/0606d27149a3b432615e25b93c360c9e38acf92e/densePointCloud.abc"
#  - logFile: /tmp/MeshroomCache/Meshing/0606d27149a3b432615e25b93c360c9e38acf92e/log
#  - elapsed time: 0:02:27.125921
#
# [10/12] MeshFiltering
#  - commandLine: aliceVision_meshFiltering  --inputMesh "/tmp/MeshroomCache/Meshing/0606d27149a3b432615e25b93c360c9e38acf92e/mesh.obj" --removeLargeTrianglesFactor 60.0 --keepLargestMeshOnly False --iterations 5 --lambda 1.0 --verboseLevel info --outputMesh "/tmp/MeshroomCache/MeshFiltering/693f21f9834e5b1a74b3c6be4bc2dfdf4e5c68b0/mesh.obj"
#  - logFile: /tmp/MeshroomCache/MeshFiltering/693f21f9834e5b1a74b3c6be4bc2dfdf4e5c68b0/log
#  - elapsed time: 0:00:01.897820
#
# [11/12] Texturing
#  - commandLine: aliceVision_texturing  --input "/tmp/MeshroomCache/Meshing/0606d27149a3b432615e25b93c360c9e38acf92e/densePointCloud.abc" --imagesFolder "/tmp/MeshroomCache/PrepareDenseScene/92f4c73cfce2d1da76aa5b0cf68c4f10573e5b39" --inputMesh "/tmp/MeshroomCache/MeshFiltering/693f21f9834e5b1a74b3c6be4bc2dfdf4e5c68b0/mesh.obj" --textureSide 8192 --downscale 1 --outputTextureFileType png --unwrapMethod Basic --useUDIM True --fillHoles False --padding 5 --correctEV False --useScore True --processColorspace sRGB --multiBandDownscale 4 --multiBandNbContrib 1 5 10 0 --bestScoreThreshold 0.1 --angleHardThreshold 90.0 --forceVisibleByAllVertices False --flipNormals False --visibilityRemappingMethod PullPush --verboseLevel info --output "/tmp/MeshroomCache/Texturing/f49044536fcc3a9a6fa9f074086486cb87afaad8"
#  - logFile: /tmp/MeshroomCache/Texturing/f49044536fcc3a9a6fa9f074086486cb87afaad8/log
#  - elapsed time: 0:00:58.175924
#
# [12/12] Publish
# Publish
# Publish file /tmp/MeshroomCache/Texturing/f49044536fcc3a9a6fa9f074086486cb87afaad8/texturedMesh.obj into /content/Project-3D/output/texturedMesh.obj
# Publish file /tmp/MeshroomCache/Texturing/f49044536fcc3a9a6fa9f074086486cb87afaad8/texturedMesh.mtl into /content/Project-3D/output/texturedMesh.mtl
# Publish file /tmp/MeshroomCache/Texturing/f49044536fcc3a9a6fa9f074086486cb87afaad8/texture_1001.png into /content/Project-3D/output/texture_1001.png
# Publish end
#  - elapsed time: 0:00:00.045147
#
# Moving output files to google drive...
#
# '/content/Project-3D/output/texture_1001.png' -> '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Output/texture_1001.png'
# '/content/Project-3D/output/texturedMesh.mtl' -> '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Output/texturedMesh.mtl'
# '/content/Project-3D/output/texturedMesh.obj' -> '/content/drive/My Drive/Colab Notebooks/3D-Reconstruction/Output/texturedMesh.obj'
#
# Removing all temporary files...
#
# removed '/content/Project-3D/input/20200411_172659.jpg'
# removed '/content/Project-3D/input/20200411_172651.jpg'
# removed '/content/Project-3D/input/20200411_172725.jpg'
# removed '/content/Project-3D/input/20200411_172542.jpg'
# removed '/content/Project-3D/input/20200411_172509.jpg'
# removed '/content/Project-3D/input/20200411_172713.jpg'
# removed '/content/Project-3D/input/20200411_172533.jpg'
# removed '/content/Project-3D/input/20200411_172527.jpg'
# removed '/content/Project-3D/input/20200411_172734.jpg'
# removed '/content/Project-3D/input/20200411_172643.jpg'
# removed '/content/Project-3D/input/20200411_172835.jpg'
# removed '/content/Project-3D/input/20200411_172547.jpg'
# removed '/content/Project-3D/input/20200411_172558.jpg'
# removed '/content/Project-3D/input/20200411_172655.jpg'
# removed '/content/Project-3D/input/20200411_172718.jpg'
# removed '/content/Project-3D/input/20200411_172625.jpg'
# removed '/content/Project-3D/input/20200411_172552.jpg'
# removed directory '/content/Project-3D/input'
# removed '/content/Project-3D/output/texturedMesh.mtl'
# removed '/content/Project-3D/output/texturedMesh.obj'
# removed '/content/Project-3D/output/texture_1001.png'
# removed directory '/content/Project-3D/output'
# #########################################################################################################################################################################################################
# #########################################################################################################################################################################################################
